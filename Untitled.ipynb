# %%
from Dataset.dataloader import getNames
from Dataset.dataloader import GetLoader
from Dewarp.Dewarp import ShowResult
from torchvision import transforms

# %%
names = getNames()
train_loader = GetLoader()

# %%
image,mask = next(iter(train_loader))
image.shape
# Out:
# torch.Size([2, 1, 1536, 1152])

# %%
ShowResult(image[0],mask[0].transpose(0,1).transpose(1,2).cpu().detach().numpy().squeeze())[1]
# Out:
# <PIL.Image.Image image mode=RGB size=1100x1500 at 0x7F735AE5DFD0>

# %%
transforms.ToPILImage()(image[0])
# Out:
# <PIL.Image.Image image mode=L size=1152x1536 at 0x7FAF92722E10>

# %%
names[0][0][0]
# Out:
# '10495.jpg'

# %%
names[1][0][0]
# Out:
# '1108.npy'
