# %%
from Dataset.dataloader import getNames
from Dataset.dataloader import GetLoader
from Dewarp.Dewarp import ShowResult
from torchvision import transforms
import matplotlib.pyplot as plt

# %% [markdown]
# In first place I started with UNet architecture and made several experiment with its parameters. To do this I created the test dataset which was random number of ellipses of different size and color on small resolution picture (64\*64) and big resolution picture (256\*256). The task was to segmentate ellipses from background.

# %%
from Ellipses.Ellipses import CreateEllipsesDataset

# %%
train_dataloader, test_dataloader = CreateEllipsesDataset()

# %%
image, mask = next(iter(train_dataloader))
plt.imshow(transforms.ToPILImage()(image[0]))
plt.show()
plt.imshow(transforms.ToPILImage()(mask[0]))
plt.show()
plt.imshow(transforms.ToPILImage()(image[1]))
plt.show()
plt.imshow(transforms.ToPILImage()(mask[1]))
plt.show()

# %%
from UNet.UNet import UNet

# %%
model = UNet()

# %%
model
# Out:
# UNet(
#   (encoder): Encoder(
#     (block1): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block2): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block3): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block4): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block5): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#   )
#   (decoder): Decoder(
#     (block4): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block3): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block2): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block1): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#   )
#   (final): Conv2d(4, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
from UNet.train import TrainNet

# %%
model=TrainNet(model,train_dataloader,test_dataloader)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-4b146bf57546> in <module>
# ----> 1 model=TrainNet(model,train_dataloader,test_dataloader)
#
# ~/DocUNet/UNet/train.py in TrainNet(model, ellipses_train_loader, ellipses_test_loader, number_of_epochs)
#      40         train_epoch(model, optimizer=optimizer,
#      41                     train_loader=ellipses_train_loader,
# ---> 42                     criterion=criterion, device='cuda')
#      43         train_loss, train_dice = evaluate_loss(loader=ellipses_train_loader, model=model,
#      44                                                criterion=criterion, device='cuda')
#
# ~/DocUNet/UNet/train.py in train_epoch(model, optimizer, train_loader, criterion, device)
#      19
#      20     for batch_train, batch_answers in train_loader:
# ---> 21         batch_train = batch_train.to(device)
#      22         batch_answers = batch_answers.to(device)
#      23
#
# RuntimeError: CUDA error: out of memory

# %%
# Load the TensorBoard notebook extension

import tensorflow as tf
import datetime, os
# %load_ext tensorboard
# %tensorboard --logdir runs --host=127.0.0.1 --port 8068
# Out:
# ERROR: Failed to launch TensorBoard (exited with 255).
# Contents of stderr:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# E0903 13:18:26.378419 MainThread program.py:201] TensorBoard could not bind to port 8068, it was already in use
# E0903 13:18:26.378418 140608891094784 program.py:201] TensorBoard could not bind to port 8068, it was already in use
# ERROR: TensorBoard could not bind to port 8068, it was already in use

# %%
from DocUNet.DocUNet import DocUNet

# %%
model=DocUNet()
model
# Out:
# DocUNet(
#   (encoder): Encoder(
#     (block1): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block2): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block3): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block4): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block5): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#   )
#   (decoder): Decoder(
#     (block4): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block3): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block2): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block1): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#   )
#   (encoder1): Encoder(
#     (block1): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(6, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block2): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block3): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block4): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block5): EncoderBlock(
#       (block): Sequential(
#         (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu1): ReLU()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu2): ReLU()
#       )
#     )
#   )
#   (decoder1): Decoder(
#     (block4): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block3): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block2): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#     (block1): DecoderBlock(
#       (uppool): Upsample(scale_factor=2.0, mode=bilinear)
#       (upconv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU()
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU()
#     )
#   )
#   (final): Conv2d(4, 2, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
from Dewarp.Dewarp import make_docunet_estimator

# %%
train_loader = GetLoader()

# %%
model = make_docunet_estimator(model,train_loader,train_loader)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-8cf3beb3eb0f> in <module>
# ----> 1 model = make_docunet_estimator(model,train_loader,train_loader)
#
# ~/DocUNet/Dewarp/Dewarp.py in make_docunet_estimator(model, train_loader, test_loader, num_of_epochs)
#      61         train_epoch(model, optimizer=optimizer,
#      62                    train_loader=train_loader,
# ---> 63                    criterion=criterion, device='cuda')
#      64         train_loss = evaluate_loss(loader=train_loader, model=model,
#      65                                            criterion=criterion, device='cuda')
#
# ~/DocUNet/Dewarp/Dewarp.py in train_epoch(model, optimizer, train_loader, criterion, device)
#      33
#      34     for batch_train, batch_answers in train_loader:
# ---> 35         batch_train = batch_train.to(device)
#      36         batch_answers = batch_answers.to(device)
#      37
#
# RuntimeError: CUDA error: out of memory

# %%
from Dewarp.Dewarp import ShowResult,GetPredMask

# %%
image,mask=next(iter(train_loader))
image[0][0].shape
# Out:
# torch.Size([1536, 1152])

# %%
ShowResult(image[0][0],GetPredMask(image[0][0],model))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-e42cbd9f1b96> in <module>
# ----> 1 ShowResult(image[0][0],GetPredMask(image[0][0],model))
#
# ~/DocUNet/Dewarp/Dewarp.py in GetPredMask(test_image, model)
#      96     test_image= test_image=transforms.ToPILImage()(test_image)
#      97     #test_image=Image.fromarray(test_image)
# ---> 98     new_mask = model(transforms.ToTensor()(test_image).unsqueeze(1).cuda()).transpose(1,2).transpose(2,3).cpu().detach().numpy().squeeze()
#      99     return new_mask
#     100
#
# RuntimeError: CUDA error: out of memory
